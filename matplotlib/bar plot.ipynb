# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
student = {'Bod': 87, 'Any': 45, "James": 100, "Mical": 65}

# %%
names = list(student.keys())
values = list(student.values())

# %%
names
# Out:
# ['Bod', 'Any', 'James', 'Mical']

# %%
values
# Out:
# [87, 45, 100, 65]

# %%
plt.bar(names, values)
plt.show()

# %%
plt.barh(names, values, color="g")
plt.show()
